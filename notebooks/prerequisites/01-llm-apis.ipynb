# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %%
# os.getenv("OPENAI_API_KEY")
#os.getenv("GOOGLE_API_KEY")
# os.getenv("GROQ_API_KEY")
ssl = os.getenv("SSL_CERT_FILE") 

print ("ssl:" ,  ssl)

# %% [markdown]
# ### OpenAI Client

# %%
import httpx  # pyright: ignore[reportMissingImports]
from openai import OpenAI  # pyright: ignore[reportMissingImports]
import openai

# CORRECT: Use Client for synchronous operations
sync_client = OpenAI(
    http_client=httpx.Client()
)

response = openai.chat.completions.create(
    model="gpt-4.1-nano-2025-04-14",
    messages=[
        {"role": "system", "content" : "You are a helpful assistant."},

        # {"role": "system", "content": "You are a helpful assistant."},
        # {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)

# %%
response.usage

# %%
response = openai.chat.completions.create(  # pyright: ignore[reportUndefinedVariable]
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)

# %%
response.usage

# %%
response = openai.chat.completions.create(  # pyright: ignore[reportUndefinedVariable]
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# ### Google genai Client

# %%
from google import genai 

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant",
              "can you print 15 random words?"]
)

print(response.text)
# Out:
# Okay, here are 15 random words for you:
#
# 1.  **Mountain**
# 2.  **Whisper**
# 3.  **Laptop**
# 4.  **Cucumber**
# 5.  **Journey**
# 6.  **Velvet**
# 7.  **Symphony**
# 8.  **Digital**
# 9.  **Starlight**
# 10. **Curiosity**
# 11. **Ocean**
# 12. **Jubilant**
# 13. **Shadow**
# 14. **Zephyr**
# 15. **Discovery**

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq  # pyright: ignore[reportMissingImports]

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Caramel
# 4. Diamond
# 5. Banana
# 6. Guitar
# 7. Snowflake
# 8. Perfume
# 9. Luggage
# 10. Pineapple
# 11. Microscope
# 12. Butterfly
# 13. Football
# 14. Harmonica
# 15. Starfish
# 16. Parakeet
# 17. Fountain
# 18. Bicycle
# 19. Kitten
# 20. Galaxy
